# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("alzheimers_encoded.csv")

# Display the columns to confirm your target variable
print("Columns in the DataFrame:", df.columns.tolist())

# Define the target column based on your data
target_column = 'Alzheimers_Diagnosis_Yes'

# Ensure the target column exists
if target_column not in df.columns:
    raise ValueError(f"The target column '{target_column}' was not found. Please verify the CSV file.")

# Split predictors and target
X = df.drop(columns=[target_column])
y = df[target_column]

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Columns in the DataFrame: ['Age', 'Education_Level', 'BMI', 'Cognitive_Test_Score', 'Physical_Activity_Level', 'Alcohol_Consumption', 'Cholesterol_Level', 'Depression_Level', 'Sleep_Quality', 'Dietary_Habits', 'Air_Pollution_Exposure', 'Social_Engagement_Level', 'Income_Level', 'Stress_Levels', 'Country_Australia', 'Country_Brazil', 'Country_Canada', 'Country_China', 'Country_France', 'Country_Germany', 'Country_India', 'Country_Italy', 'Country_Japan', 'Country_Mexico', 'Country_Norway', 'Country_Russia', 'Country_Saudi_Arabia', 'Country_South_Africa', 'Country_South_Korea', 'Country_Spain', 'Country_Sweden', 'Country_UK', 'Country_USA', 'Smoking_Status_Former', 'Smoking_Status_Never', 'Employment_Status_Retired', 'Employment_Status_Unemployed', 'Marital_Status_Single', 'Marital_Status_Widowed', 'Gender_Male', 'Diabetes_Yes', 'Hypertension_Yes', 'Family_History_of_Alzheimers_Yes', 'Genetic_Risk_Factor_(APOE-ε4_allele)_Yes', 'Urban_vs_Rural_Living_Urban', 'Alzheimers_Diagnosis_Yes']
# ...

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# Load your dataset
df = pd.read_csv("alzheimers_encoded.csv")

# Define the target and features.
target_column = 'Alzheimers_Diagnosis_Yes'
X = df.drop(columns=[target_column])
y = df[target_column]

print("Original features shape:", X.shape)

# Generate pairwise interaction features (degree 2, interactions only)
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_interact = poly.fit_transform(X)

print("Number of features after adding interactions:", X_interact.shape[1])

# Initialize a logistic regression model
model = LogisticRegression(max_iter=1000, solver='liblinear')

# Evaluate the model using cross-validation on the original features
cv_scores_orig = cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("CV Accuracy with original features:", cv_scores_orig.mean())

# Evaluate the model using cross-validation on the expanded feature set
cv_scores_interact = cross_val_score(model, X_interact, y, cv=5, scoring='accuracy')
print("CV Accuracy with interaction features:", cv_scores_interact.mean())
# Out:
# Original features shape: (74283, 45)
# Number of features after adding interactions: 1035
# CV Accuracy with original features: 0.7152242928084573
# CV Accuracy with interaction features: 0.7113337837953922
